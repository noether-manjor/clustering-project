# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

import os

# %%
def get_wine_data():
    filename = "winequality-red.csv"

    if os.path.isfile(filename):
        return pd.read_csv(filename)

# %%
red_wine = pd.read_csv('winequality-red.csv')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine.insert(12, column="wine_color", value='red')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality wine_color
# 0      9.4        5        red
# 1      9.8        5        red
# 2      9.8        5        red
# 3      9.8        6        red
# 4      9.4        5        red

# %%
white_wine = pd.read_csv('winequality-white.csv')
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white_wine.insert(12, column="wine_color", value='white')
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality wine_color
# 0      8.8        6      white
# 1      9.5        6      white
# 2     10.1        6      white
# 3      9.9        6      white
# 4      9.9        6      white

# %%
frames = [red_wine, white_wine]

wines = pd.concat(frames)

wines = wines.reset_index(drop=True)

wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality wine_color
# 0         9.4        5        red
# 1         9.8        5        red
# 2         9.8        5        red
# 3         9.8        6        red
# 4         9.4        5        red
# ...       ...      ...        ...
# 6492     11.2        6      white
# 6493      9.6        5      white
# 6494      9.4        6      white
# 6495     12.8        7      white
# 6496     11.8        6      white
#
# [6497 rows x 13 columns]

# %%
def overview(df):
    '''
    print shape of DataFrame, .info, and .describe
    parameters: single pandas dataframe, df
    return: none
    '''
    print('--- Shape: {}'.format(df.shape))
    print('____________________________________________________')
    print('--- Info')
    df.info()
    print('____________________________________________________')
    print('--- Column Descriptions')
    print()
    print(df.describe())

# %%
overview(wines)
# Out:
# --- Shape: (6497, 13)
# ____________________________________________________
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_color            6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB
# ____________________________________________________
# --- Column Descriptions
#
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
wines["free sulfur dioxide"] = wines["free sulfur dioxide"].astype(int)
wines["total sulfur dioxide"] = wines["total sulfur dioxide"].astype(int)

# %%
wines = wines.rename(columns={'fixed acidity':'fixed_acidity', 
                            'volatile acidity':'volatile_acidity', 
                            'citric acid':'citric_acid',
                            'residual sugar':'residual_sugar', 
                            'free sulfur dioxide':'free_sulfur_dioxide',
                            'total sulfur dioxide':'total_sulfur_dioxide'
                            })

# %%
wines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                      11                    34  0.99780  3.51       0.56
# 1                      25                    67  0.99680  3.20       0.68
# 2                      15                    54  0.99700  3.26       0.65
# 3                      17                    60  0.99800  3.16       0.58
# 4                      11                    34  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                   24                    92  0.99114  3.27       0.50
# 6493                   57                   168  0.99490  3.15       0.46
# 6494                   30                   111  0.99254  2.99       0.46
# 6495                   20                   110  0.98869  3.34       0.38
# 6496                   22                    98  0.98941  3.26       0.32
#
#       alcohol  quality wine_color
# 0         9.4        5        red
# 1         9.8        5        red
# 2         9.8        5        red
# 3         9.8        6        red
# 4         9.4        5        red
# ...       ...      ...        ...
# 6492     11.2        6      white
# 6493      9.6        5      white
# 6494      9.4        6      white
# 6495     12.8        7      white
# 6496     11.8        6      white
#
# [6497 rows x 13 columns]

# %%
num_cols = list(wines.select_dtypes(exclude=object).columns.values)

for col in num_cols:
    
    plt.boxplot(wines[col])
    plt.title(f'distribution of {col}')
    plt.show()

# %%
def outlier_bound_calculation(df, variable):
    '''
    This function calcualtes the lower and upper bound 
    to locate outliers in the variable named
    '''
    quartile1, quartile3 = np.percentile(df[variable], [25,75])
    IQR_value = quartile3 - quartile1
    lower_bound = quartile1 - (1.5 * IQR_value)
    upper_bound = quartile3 + (1.5 * IQR_value)
    '''
    returns the lowerbound and upperbound values
    '''
    return print(f'For {variable} the lower bound is {lower_bound} and  upper bound is {upper_bound}')

# %%
num_df = wines.select_dtypes(exclude=object)

cols = num_df.columns.to_list()    

for col in cols:
    outlier_bound_calculation(num_df, [col])
# Out:
# For ['fixed_acidity'] the lower bound is 4.450000000000001 and  upper bound is 9.65
# For ['volatile_acidity'] the lower bound is -0.024999999999999994 and  upper bound is 0.655
# For ['citric_acid'] the lower bound is 0.03999999999999998 and  upper bound is 0.6000000000000001
# For ['residual_sugar'] the lower bound is -7.6499999999999995 and  upper bound is 17.549999999999997
# For ['chlorides'] the lower bound is -0.002500000000000009 and  upper bound is 0.10550000000000001
# For ['free_sulfur_dioxide'] the lower bound is -19.0 and  upper bound is 77.0
# For ['total_sulfur_dioxide'] the lower bound is -41.5 and  upper bound is 274.5
# For ['density'] the lower bound is 0.9853649999999999 and  upper bound is 1.003965
# For ['pH'] the lower bound is 2.795 and  upper bound is 3.635
# For ['sulphates'] the lower bound is 0.175 and  upper bound is 0.855
# For ['alcohol'] the lower bound is 6.799999999999999 and  upper bound is 14.000000000000002
# For ['quality'] the lower bound is 3.5 and  upper bound is 7.5

# %%
def remove_outliers(df,col_list,k):
    ''' 
    This function takes in a dataframe, the threshold and a list of columns 
    and returns the dataframe with outliers removed
    '''   
    for col in col_list:

        q1, q3 = df[col].quantile([.25, .75])  # get quartiles
        
        iqr = q3 - q1   # calculate interquartile range
        
        upper_bound = q3 + k * iqr   # get upper bound
        lower_bound = q1 - k * iqr   # get lower bound

        # return dataframe without outliers
        
        df = df[(df[col] > lower_bound) & (df[col] < upper_bound)]
        
    return df

# %%
col_list = ['fixed_acidity', 'volatile_acidity', 'citric_acid',
                            'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
                            'total_sulfur_dioxide', 'density', 'pH', 'sulphates',
                            'alcohol']
            
wines = remove_outliers(wines, col_list, k=1.5)
wines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 20              8.9             0.220         0.48             1.8      0.077
# 25              6.3             0.390         0.16             1.4      0.080
# 26              7.6             0.410         0.24             1.8      0.080
# 33              6.9             0.605         0.12            10.7      0.073
# 37              8.1             0.380         0.28             2.1      0.066
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.210         0.29             1.6      0.039
# 6493            6.6             0.320         0.36             8.0      0.047
# 6494            6.5             0.240         0.19             1.2      0.041
# 6495            5.5             0.290         0.30             1.1      0.022
# 6496            6.0             0.210         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 20                     29                    60  0.99680  3.39       0.53
# 25                     11                    23  0.99550  3.34       0.56
# 26                      4                    11  0.99620  3.28       0.59
# 33                     40                    83  0.99930  3.45       0.52
# 37                     13                    30  0.99680  3.23       0.73
# ...                   ...                   ...      ...   ...        ...
# 6492                   24                    92  0.99114  3.27       0.50
# 6493                   57                   168  0.99490  3.15       0.46
# 6494                   30                   111  0.99254  2.99       0.46
# 6495                   20                   110  0.98869  3.34       0.38
# 6496                   22                    98  0.98941  3.26       0.32
#
#       alcohol  quality wine_color
# 20        9.4        6        red
# 25        9.3        5        red
# 26        9.5        5        red
# 33        9.4        6        red
# 37        9.7        7        red
# ...       ...      ...        ...
# 6492     11.2        6      white
# 6493      9.6        5      white
# 6494      9.4        6      white
# 6495     12.8        7      white
# 6496     11.8        6      white
#
# [4550 rows x 13 columns]

# %%
num_cols = list(wines.select_dtypes(exclude=object).columns.values)

for col in num_cols:
    
    plt.boxplot(wines[col])
    plt.title(f'distribution of {col}')
    plt.show()

# %%
def split_data(df, target):
    '''
    This function take in a dataframe performs a train, validate, test split
    Returns train, validate, test, X_train, y_train, X_validate, y_validate, X_test, y_test
    and prints out the shape of train, validate, test
    '''
    #create train_validate and test datasets
    train, test = train_test_split(df, train_size = 0.8, random_state = 123)
    #create train and validate datasets
    train, validate = train_test_split(train, train_size = 0.7, random_state = 123)

    #Split into X and y
    X_train = train.drop(columns=[target])
    y_train = train[target]

    X_validate = validate.drop(columns=[target])
    y_validate = validate[target]

    X_test = test.drop(columns=[target])
    y_test = test[target]

    # Have function print datasets shape
    print(f'train -> {train.shape}')
    print(f'validate -> {validate.shape}')
    print(f'test -> {test.shape}')
   
    return train, validate, test, X_train, y_train, X_validate, y_validate, X_test, y_test

# %%
train, validate, test, X_train, y_train, X_validate, y_validate, X_test, y_test = split_data(wines, 
                                                                                             'quality')
# Out:
# train -> (2548, 13)
# validate -> (1092, 13)
# test -> (910, 13)

# %%
num_cols = list(train.select_dtypes(exclude=object).columns.values)

for col in num_cols:
    
    plt.hist(train[col])
    plt.title(f'distribution of {col}')
    plt.show()

# %%
to_dummy = ['wine_color']
# Create dummies for non-binart categorical variables
dummies = pd.get_dummies(train[to_dummy], drop_first=False)
train = pd.concat([train, dummies], axis=1)

# %%
drop = ['wine_color']
train.drop(columns=drop, inplace=True)

# %%
train.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1718            7.3              0.32         0.48            13.3      0.060
# 3520            7.6              0.13         0.34             9.3      0.062
# 1733            6.8              0.27         0.22             8.1      0.034
# 2539            6.2              0.34         0.28             7.5      0.034
# 4367            7.7              0.30         0.34             1.2      0.048
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1718                   57                   196  0.99820  3.04       0.50
# 3520                   40                   126  0.99660  3.21       0.39
# 1733                   55                   203  0.99610  3.19       0.52
# 2539                   40                   197  0.99485  3.14       0.60
# 4367                    4                   119  0.99084  3.18       0.34
#
#       alcohol  quality  wine_color_red  wine_color_white
# 1718      9.2        5               0                 1
# 3520      9.6        5               0                 1
# 1733      8.9        5               0                 1
# 2539      9.7        5               0                 1
# 4367     12.1        6               0                 1

# %%
train_corr = train.corr()
train_corr
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.074208     0.257376
# volatile_acidity           0.074208          1.000000    -0.236991
# citric_acid                0.257376         -0.236991     1.000000
# residual_sugar            -0.002005         -0.043550     0.031356
# chlorides                  0.204009          0.289336    -0.074604
# free_sulfur_dioxide       -0.122611         -0.203564     0.097760
# total_sulfur_dioxide      -0.082271         -0.127342     0.114764
# density                    0.271485          0.098925     0.021801
# pH                        -0.298741          0.116224    -0.131009
# sulphates                  0.057718          0.128563     0.018207
# alcohol                   -0.087502          0.046222     0.036914
# quality                   -0.058876         -0.167727     0.068045
# wine_color_red             0.246610          0.451596    -0.122631
# wine_color_white          -0.246610         -0.451596     0.122631
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity              -0.002005   0.204009            -0.122611
# volatile_acidity           -0.043550   0.289336            -0.203564
# citric_acid                 0.031356  -0.074604             0.097760
# residual_sugar              1.000000   0.084294             0.378928
# chlorides                   0.084294   1.000000            -0.043929
# free_sulfur_dioxide         0.378928  -0.043929             1.000000
# total_sulfur_dioxide        0.461660  -0.029936             0.655571
# density                     0.754038   0.502313             0.248458
# pH                         -0.201432   0.155384            -0.057360
# sulphates                  -0.106754   0.234671            -0.048502
# alcohol                    -0.451708  -0.438705            -0.235982
# quality                    -0.101208  -0.244236             0.018282
# wine_color_red             -0.221837   0.584566            -0.303132
# wine_color_white            0.221837  -0.584566             0.303132
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.082271  0.271485 -0.298741   0.057718
# volatile_acidity                 -0.127342  0.098925  0.116224   0.128563
# citric_acid                       0.114764  0.021801 -0.131009   0.018207
# residual_sugar                    0.461660  0.754038 -0.201432  -0.106754
# chlorides                        -0.029936  0.502313  0.155384   0.234671
# free_sulfur_dioxide               0.655571  0.248458 -0.057360  -0.048502
# total_sulfur_dioxide              1.000000  0.368954 -0.119227  -0.079754
# density                           0.368954  1.000000  0.017390   0.129572
# pH                               -0.119227  0.017390  1.000000   0.242739
# sulphates                        -0.079754  0.129572  0.242739   1.000000
# alcohol                          -0.398881 -0.797105  0.058722  -0.025422
# quality                          -0.140908 -0.313083  0.053112   0.035990
# wine_color_red                   -0.499527  0.179056  0.282310   0.336186
# wine_color_white                  0.499527 -0.179056 -0.282310  -0.336186
#
#                        alcohol   quality  wine_color_red  wine_color_white
# fixed_acidity        -0.087502 -0.058876        0.246610         -0.246610
# volatile_acidity      0.046222 -0.167727        0.451596         -0.451596
# citric_acid           0.036914  0.068045       -0.122631          0.122631
# residual_sugar       -0.451708 -0.101208       -0.221837          0.221837
# chlorides            -0.438705 -0.244236        0.584566         -0.584566
# free_sulfur_dioxide  -0.235982  0.018282       -0.303132          0.303132
# total_sulfur_dioxide -0.398881 -0.140908       -0.499527          0.499527
# density              -0.797105 -0.313083        0.179056         -0.179056
# pH                    0.058722  0.053112        0.282310         -0.282310
# sulphates            -0.025422  0.035990        0.336186         -0.336186
# alcohol               1.000000  0.433041        0.005894         -0.005894
# quality               0.433041  1.000000       -0.038404          0.038404
# wine_color_red        0.005894 -0.038404        1.000000         -1.000000
# wine_color_white     -0.005894  0.038404       -1.000000          1.000000

# %%
sns.heatmap(train_corr, cmap='Purples', linewidth=0.5, linecolor='black')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train.quality, y=train.alcohol)
plt.title("Does a higher quality mean higher alcohol content?")
plt.show()

# %%
sns.barplot(data=wines, x='wine_color', y='quality')
plt.title("Does color affect wine quality?")
plt.show()

# %%
sns.relplot(data=wines, x ='wine_color', y='quality', kind='line')
plt.title("Does color affect wine quality?")
# Out:
# Text(0.5, 1.0, 'Does color affect wine quality?')

# %%
wines.quality.value_counts()
# Out:
# 6    2074
# 5    1306
# 7     873
# 8     162
# 4     119
# 3      11
# 9       5
# Name: quality, dtype: int64

# %%
# code to generate baseline 
wines['baseline'] = wines['quality'].value_counts().idxmax()
(wines['quality'] == wines['baseline']).mean()
# clean f string
print(f"Baseline: {(wines['quality'] == wines['baseline']).mean()*100:.2f}%")
# Out:
# Baseline: 45.58%
